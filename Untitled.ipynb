# %%
import pandas.rpy.common as com
from prettypandas import PrettyPandas
filename = "data/HealthPlan/Beweging module 1.sav"
w = com.robj.r('foreign::read.spss("%s", to.data.frame=TRUE)' % filename)
w = com.convert_robj(w)
print len(w.columns)
table = PrettyPandas(w.head(5))
table
# Out:
# 327
#         <style  type="text/css" >
#
#             #T_dc8d5202_7ff2_11e6_b6e5_34e6d711c480 th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_dc8d5202_7ff2_11e6_b6e5_34e6d711c480 td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_dc8d5202_7ff2_11e6_b6e5_34e6d711c480 * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_dc8d5202_7ff2_11e6_b6e5_34e6d711c480" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">token
#
#                 <th class="col_heading level0 col1">firstname
#
#                 <th class="col_heading level0 col2">lastname
#
#                 <th class="col_heading level0 col3">email
#
#                 <th class="col_heading level0 col4">language
#
#                 <th class="col_heading level0 col5">sent
#
#                 <th class="col_heading level0 col6">remindersent
#
#                 <th class="col_heading level0 col7">remindercount
#
#                 <th class="col_heading level0 col8">usesleft
#
#                 <th class="col_heading level0 col9">id
#
#                 <th class="col_heading level0 col10">submitdate
#
#                 <th class="col_heading level0 col11">startlanguage
#
#                 <th class="col_heading level0 col12">ipaddr
#
#                 <th class="col_heading level0 col13">refurl
#
#                 <th class="col_heading level0 col14">STARTDATUM
#
#                 <th class="col_heading level0 col15">INGEVULD
#
#                 <th class="col_heading level0 col16">Leeftijd
#
#                 <th class="col_heading level0 col17">GESLACHT
#
#                 <th class="col_heading level0 col18">DIPLOMA
#
#                 <th class="col_heading level0 col19">GEWICHT
#
#                 <th class="col_heading level0 col20">LENGTE
#
#                 <th class="col_heading level0 col21">PP1
#
#                 <th class="col_heading level0 col22">PP2
#
#                 <th class="col_heading level0 col23">PP3
#
#                 <th class="col_heading level0 col24">PP4
#
#                 <th class="col_heading level0 col25">BMI
#
#                 <th class="col_heading level0 col26">B2C
#
#                 <th class="col_heading level0 col27">B2D
#
#                 <th class="col_heading level0 col28">B2E
#
#                 <th class="col_heading level0 col29">B2F
#
#                 <th class="col_heading level0 col30">B2G
#
#                 <th class="col_heading level0 col31">B2H
#
#                 <th class="col_heading level0 col32">B3C
#
#                 <th class="col_heading level0 col33">B3D
#
#                 <th class="col_heading level0 col34">B3A
#
#                 <th class="col_heading level0 col35">B3B
#
#                 <th class="col_heading level0 col36">B3E
#
#                 <th class="col_heading level0 col37">B3F
#
#                 <th class="col_heading level0 col38">B4F
#
#                 <th class="col_heading level0 col39">B4G
#
#                 <th class="col_heading level0 col40">B4D
#
#                 <th class="col_heading level0 col41">B4E
#
#                 <th class="col_heading level0 col42">B4A
#
#                 <th class="col_heading level0 col43">B4B
#
#                 <th class="col_heading level0 col44">B4C
#
#                 <th class="col_heading level0 col45">B1A
#
#                 <th class="col_heading level0 col46">B1D
#
#                 <th class="col_heading level0 col47">B1E
#
#                 <th class="col_heading level0 col48">B1B
#
#                 <th class="col_heading level0 col49">B1C
#
#                 <th class="col_heading level0 col50">B1F
#
#                 <th class="col_heading level0 col51">B1G
#
#                 <th class="col_heading level0 col52">B1H
#
#                 <th class="col_heading level0 col53">B2CD
#
#                 <th class="col_heading level0 col54">B2CDHIGH
#
#                 <th class="col_heading level0 col55">B2CDMOD
#
#                 <th class="col_heading level0 col56">B2FG
#
#                 <th class="col_heading level0 col57">B2FGMOD
#
#                 <th class="col_heading level0 col58">B2FGLOW
#
#                 <th class="col_heading level0 col59">TRANSPORTMI
#
#                 <th class="col_heading level0 col60">B3CD
#
#                 <th class="col_heading level0 col61">B3AB
#
#                 <th class="col_heading level0 col62">B3EF
#
#                 <th class="col_heading level0 col63">B4FG
#
#                 <th class="col_heading level0 col64">B4DE
#
#                 <th class="col_heading level0 col65">B4AB
#
#                 <th class="col_heading level0 col66">B4ABMOD
#
#                 <th class="col_heading level0 col67">B4ABLOW
#
#                 <th class="col_heading level0 col68">FAVRIJMI
#
#                 <th class="col_heading level0 col69">B1DE
#
#                 <th class="col_heading level0 col70">B1BC
#
#                 <th class="col_heading level0 col71">B1FG
#
#                 <th class="col_heading level0 col72">B1FGMOD
#
#                 <th class="col_heading level0 col73">B1FGLOW
#
#                 <th class="col_heading level0 col74">FAMR
#
#                 <th class="col_heading level0 col75">FAIR
#
#                 <th class="col_heading level0 col76">FATOTR
#
#                 <th class="col_heading level0 col77">FAMR_1680
#
#                 <th class="col_heading level0 col78">FAIR_780
#
#                 <th class="col_heading level0 col79">FATOTR_2540
#
#                 <th class="col_heading level0 col80">FAMK
#
#                 <th class="col_heading level0 col81">FATOTK
#
#                 <th class="col_heading level0 col82">FAIK
#
#                 <th class="col_heading level0 col83">FAM
#
#                 <th class="col_heading level0 col84">FATOT
#
#                 <th class="col_heading level0 col85">FAI
#
#                 <th class="col_heading level0 col86">FAMD
#
#                 <th class="col_heading level0 col87">FAID
#
#                 <th class="col_heading level0 col88">FATOTD
#
#                 <th class="col_heading level0 col89">FAVRIJTOT
#
#                 <th class="col_heading level0 col90">FAVRIJI
#
#                 <th class="col_heading level0 col91">TRANSP
#
#                 <th class="col_heading level0 col92">TUIN
#
#                 <th class="col_heading level0 col93">FAV
#
#                 <th class="col_heading level0 col94">FATOTMID
